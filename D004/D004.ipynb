# %% [markdown]
# 📝 데이터 분석 보고서 (양식 예시)
#
# 1. 분석 개요
# ▸ 대상: 모두마켓 주문 1,500건 (2025-01 ~ 2025-05), 고객·상품 정보 병합
# ▸ 방법: 3개 테이블 키 검증 후 m:1 병합 → 월별 KPI 집계 → 교차표·점유율 분석
#
# 2. 핵심 발견
# ▸ 매출이 가장 높았던 분기는 {Q1} 이었으며, 2분기는 전 분기 대비 매출증감률(-40.4%)을 기록함.
# ▸ 카테고리 중 {패션}, 지역 중 {인천} 의 매출 기여가 가장 컸음.
# ▸ 전체 객단가는 약 {60,637}원.
#
# 3. 데이터 신뢰성 (반드시 기록)
# ▸ 병합 전 키 검증: 중복 0건, 미매칭 0건 → 행 폭증·조용한 결측 없음.
# ▸ validate="m:1" 통과 → 관계 가정(주문:상품 = m:1) 유효.
#
# 4. 제언
# ▸ 분기별 매출 변동의 원인을 구매고객수·객단가 열로 분해해 마케팅 전략 차별화가 필요하며, 인천 지역의 경우 총 매출 기여도는 가장 높았으나 VIP 등급의 매출이 타 지역 대비 눈에 띄게 상대적 약세를 띄고 있어 VIP를 대상으로 한 매출 개선 전략 또는 지역 내 소비성향을 추가조사하여 지역의 멤버십 등급별 수요를 파악 후 고객 이탈 방지를 위한 재구매 혜택 등 맞춤 전략 실시 필요
