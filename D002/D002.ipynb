# %% [markdown]
# ## 필수 과제
#
# - shape·info·describe로 구조 진단을 수행하고, 발견한 점을 글로 정리했다.
# - 결측·중복·표기 문제를 각각 코드로 확인하고 개선·종류를 적었다.
# - 추이·관계 중 2개 이상의 차트를 목적에 맞게 그렸다.
# - 마무리 EDA 리포트 양식(5개 항목)을 모두 채웠다.
#
# ## 심화 과제 (선택)
#
# - 따릉이 데이터의 rainfall(강수량)과 rentals의 관계를 추가로 시각화했다.
# - 이상치와 결측치를 어떻게 처리하면 좋을지 본인 생각을 적었다.
